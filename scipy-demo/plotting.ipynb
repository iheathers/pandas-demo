# %%
import pandas as pd

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
tips.tip.plot(kind='hist', edgecolor='red')

# %%
tips.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips.smoker.value_counts().plot(kind='bar')

# %%
sns.countplot(x='smoker', data=tips)

# %%
sns.countplot(y='smoker', data=tips)

# %%
sns.distplot(tips.total_bill, )

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='smoker', row='day')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
facet = sns.FacetGrid(tips, row='smoker', col='time', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %%
facet = sns.FacetGrid(tips, row='smoker', col='time', hue='sex')

# %%
fig, ax = plt.subplots()
ax.scatter(tips.tip, tips.total_bill)

# %%
ax.scatter(tips.tip, tips.total_bill)

# %%
plt.show()

# %%
fig.show()
# Out:
# C:\Users\pshre\anaconda3\envs\deep-learning\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
dis = sns.distplot(tips.tip)
